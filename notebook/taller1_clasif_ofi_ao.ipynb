# %% [markdown]
# ## 5. 🔎 Análisis Exploratorio de Datos

# %% [markdown]
# ### 5.1 Carga de librerías y datos

# %% [markdown]
# En esta sección se realiza la carga de las librerías necesarias para la exploración, análisis y visualización del conjunto de datos. Posteriormente, se importa el archivo `Data_set.csv`, que contiene la información de las unidades analizadas y las variables relacionadas con Riesgo Psicosocial, Evaluación del Desempeño y Engagement.

# %%
# Librerías para manipulación y análisis de datos
import pandas as pd
import numpy as np

# Librerías para visualización
# import matplotlib.pyplot as plt
import seaborn as sns

# Configuración para visualizar todas las columnas
pd.set_option('display.max_columns', None)

# Carga del conjunto de datos
df = pd.read_csv('../data/Data_set.csv', delimiter=';')

# %% [markdown]
# ### 5.2 Exploración y calidad de los datos

# %%
# Información general del conjunto de datos
df.info()

# Visualización de los primeros registros
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 61 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   REGIONAL                                                    273 non-null    str
#  1   CODIGO UNIDAD                                               273 non-null    str
#  2   TIPO                                                        273 non-null    str
#  3   APERTURA                                                    273 non-null    int64
#  4   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy alto          221 non-null    str
#  5   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto              221 non-null    str
#  6   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio             221 non-null    str
#  7   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo              221 non-null    str
#  8   Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo               221 non-null    str
#  9   Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo muy alto  221 non-null    str
#  10  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo alto      221 non-null    str
#  11  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo medio     221 non-null    str
#  12  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo bajo      221 non-null    str
#  13  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin riesgo       221 non-null    str
#  14  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo muy alto    221 non-null    str
#  15  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo alto        221 non-null    str
#  16  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo medio       221 non-null    str
#  17  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo bajo        221 non-null    str
#  18  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin riesgo         221 non-null    str
#  19  Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo muy alto          206 non-null    str
#  20  Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo alto              206 non-null    str
#  21  Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo medio             206 non-null    str
#  22  Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo bajo              206 non-null    str
#  23  Riesgo psicosocial_AÑO 2023_ESTRÉS_Sin riesgo               206 non-null    str
#  24  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo muy alto  206 non-null    str
#  25  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo alto      206 non-null    str
#  26  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo medio     206 non-null    str
#  27  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo bajo      206 non-null    str
#  28  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Sin riesgo       206 non-null    str
#  29  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo muy alto    206 non-null    str
#  30  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo alto        206 non-null    str
#  31  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo medio       206 non-null    str
#  32  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo bajo        206 non-null    str
#  33  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Sin riesgo         206 non-null    str
#  34  Evaluación del desempeño_AÑO 2025_OBJETIVO                  273 non-null    str
#  35  Evaluación del desempeño_AÑO 2025_COMPETENCIA               273 non-null    str
#  36  Evaluación del desempeño_AÑO 2025_RESULTADO                 273 non-null    str
#  37  Evaluación del desempeño_AÑO 2025_INTERPRETACION            273 non-null    str
#  38  Evaluación del desempeño_AÑO 2024_OBJETIVO                  269 non-null    str
#  39  Evaluación del desempeño_AÑO 2024_COMPETENCIA               269 non-null    str
#  40  Evaluación del desempeño_AÑO 2024_RESULTADO                 269 non-null    str
#  41  Evaluación del desempeño_AÑO 2024_INTERPRETACION            269 non-null    str
#  42  Evaluación del desempeño_AÑO 2023_OBJETIVO                  269 non-null    str
#  43  Evaluación del desempeño_AÑO 2023_COMPETENCIA               269 non-null    str
#  44  Evaluación del desempeño_AÑO 2023_RESULTADO                 269 non-null    str
#  45  Evaluación del desempeño_AÑO 2023_INTERPRETACION            269 non-null    str
#  46  Evaluación del desempeño_AÑO 2022_OBJETIVO                  252 non-null    str
#  47  Evaluación del desempeño_AÑO 2022_COMPETENCIA               252 non-null    str
#  48  Evaluación del desempeño_AÑO 2022_RESULTADO                 252 non-null    str
#  49  Evaluación del desempeño_AÑO 2022_INTERPRETACION            252 non-null    str
#  50  Evaluación del desempeño_AÑO 2021_OBJETIVO                  252 non-null    str
#  51  Evaluación del desempeño_AÑO 2021_COMPETENCIA               252 non-null    str
#  52  Evaluación del desempeño_AÑO 2021_RESULTADO                 252 non-null    str
#  53  Evaluación del desempeño_AÑO 2021_INTERPRETACION            252 non-null    str
#  54  Evaluación del desempeño_AÑO 2020_OBJETIVO                  252 non-null    str
#  55  Evaluación del desempeño_AÑO 2020_COMPETENCIA               252 non-null    str
#  56  Evaluación del desempeño_AÑO 2020_RESULTADO                 252 non-null    str
#  57  Evaluación del desempeño_AÑO 2020_INTERPRETACION            252 non-null    str
#  58  Engagement_AÑO 2025_AMBIENTE LABORAL                        268 non-null    str
#  59  Engagement_AÑO 2025_COMPROMISO                              268 non-null    str
#  60  Engagement_AÑO 2025_INTERPRETACION                          267 non-null    str
# dtypes: int64(1), str(60)
# memory usage: 130.2 KB
#   REGIONAL CODIGO UNIDAD      TIPO  APERTURA  \
# 0    CAUCA  A4112         Regional     42036
# 1    CAUCA  A411243            PDA     39539
# 2    CAUCA  A411242            PDA     40026
# 3    CAUCA  A411221            PDA     43661
# 4    CAUCA  A411241            PDA     39539
#
#   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy alto  \
# 0                                        0,315589354
# 1                                        0,222222222
# 2                                        0,444444444
# 3                                        0,333333333
# 4                                              0,125
#
#   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto  \
# 0                                    0,247148289
# 1                                    0,222222222
# 2                                    0,333333333
# 3                                    0,166666667
# 4                                            0,5
#
#   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio  \
# 0                                     0,216730038
# 1                                     0,333333333
# 2                                     0,222222222
# 3                                             0,5
# 4                                               0
#
#   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo  \
# 0                                    0,106463878
# 1                                    0,222222222
# 2                                              0
# 3                                              0
# 4                                              0
#
#   Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo  \
# 0                                   0,114068441
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                         0,375
#
#   Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo muy alto  \
# 0                                        0,133079848
# 1                                        0,222222222
# 2                                        0,222222222
# 3                                                  0
# 4                                                  0
#
#   Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo alto  \
# 0                                        0,201520913
# 1                                        0,222222222
# 2                                        0,222222222
# 3                                                  0
# 4                                                  0
#
#   Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo medio  \
# 0                                        0,258555133
# 1                                        0,333333333
# 2                                        0,111111111
# 3                                        0,666666667
# 4                                               0,25
#
#   Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo bajo  \
# 0                                        0,220532319
# 1                                        0,111111111
# 2                                        0,444444444
# 3                                        0,166666667
# 4                                               0,25
#
#   Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin riesgo  \
# 0                                        0,186311787
# 1                                        0,111111111
# 2                                                  0
# 3                                        0,166666667
# 4                                                0,5
#
#   Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo muy alto  \
# 0                                        0,197718631
# 1                                        0,111111111
# 2                                        0,111111111
# 3                                                  0
# 4                                              0,125
#
#   Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo alto  \
# 0                                        0,212927757
# 1                                        0,222222222
# 2                                        0,333333333
# 3                                        0,666666667
# 4                                               0,25
#
#   Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo medio  \
# 0                                         0,25095057
# 1                                        0,555555556
# 2                                        0,333333333
# 3                                        0,333333333
# 4                                              0,125
#
#   Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo bajo  \
# 0                                        0,140684411
# 1                                        0,111111111
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin riesgo  \
# 0                                        0,197718631
# 1                                                  0
# 2                                        0,222222222
# 3                                                  0
# 4                                                0,5
#
#   Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo muy alto  \
# 0                                        0,162629758
# 1                                        0,363636364
# 2                                        0,416666667
# 3                                        0,666666667
# 4                                        0,142857143
#
#   Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo alto  \
# 0                                    0,186851211
# 1                                    0,181818182
# 2                                    0,166666667
# 3                                              0
# 4                                    0,285714286
#
#   Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo medio  \
# 0                                     0,242214533
# 1                                               0
# 2                                     0,166666667
# 3                                     0,111111111
# 4                                     0,285714286
#
#   Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo bajo  \
# 0                                    0,155709343
# 1                                    0,272727273
# 2                                           0,25
# 3                                    0,111111111
# 4                                    0,285714286
#
#   Riesgo psicosocial_AÑO 2023_ESTRÉS_Sin riesgo  \
# 0                                   0,252595156
# 1                                   0,181818182
# 2                                             0
# 3                                   0,111111111
# 4                                             0
#
#   Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo muy alto  \
# 0                                        0,093425606
# 1                                        0,090909091
# 2                                        0,083333333
# 3                                        0,222222222
# 4                                                  0
#
#   Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo alto  \
# 0                                        0,173010381
# 1                                        0,090909091
# 2                                        0,333333333
# 3                                        0,222222222
# 4                                                  0
#
#   Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo medio  \
# 0                                        0,211072664
# 1                                        0,181818182
# 2                                        0,333333333
# 3                                        0,555555556
# 4                                        0,142857143
#
#   Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo bajo  \
# 0                                        0,249134948
# 1                                        0,454545455
# 2                                        0,166666667
# 3                                                  0
# 4                                        0,571428571
#
#   Riesgo psicosocial_AÑO 2023_INTRALABORALES_Sin riesgo  \
# 0                                        0,273356401
# 1                                        0,181818182
# 2                                        0,083333333
# 3                                                  0
# 4                                        0,285714286
#
#   Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo muy alto  \
# 0                                        0,162629758
# 1                                        0,181818182
# 2                                               0,25
# 3                                        0,444444444
# 4                                        0,142857143
#
#   Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo alto  \
# 0                                        0,186851211
# 1                                        0,090909091
# 2                                               0,25
# 3                                        0,333333333
# 4                                        0,142857143
#
#   Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo medio  \
# 0                                        0,242214533
# 1                                        0,363636364
# 2                                        0,083333333
# 3                                        0,222222222
# 4                                                  0
#
#   Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo bajo  \
# 0                                        0,155709343
# 1                                        0,363636364
# 2                                        0,166666667
# 3                                                  0
# 4                                        0,285714286
#
#   Riesgo psicosocial_AÑO 2023_EXTRABORALES_Sin riesgo  \
# 0                                        0,252595156
# 1                                                  0
# 2                                               0,25
# 3                                                  0
# 4                                        0,428571429
#
#   Evaluación del desempeño_AÑO 2025_OBJETIVO  \
# 0                                0,897255455
# 1                                0,807467273
# 2                                0,835372727
# 3                                  0,8219625
# 4                                 0,87932875
#
#   Evaluación del desempeño_AÑO 2025_COMPETENCIA  \
# 0                                   0,885714286
# 1                                   0,847272727
# 2                                   0,865454545
# 3                                   0,867857143
# 4                                   0,879107143
#
#   Evaluación del desempeño_AÑO 2025_RESULTADO  \
# 0                                 0,893793104
# 1                                 0,819408909
# 2                                 0,844397273
# 3                                 0,835730893
# 4                                 0,879262268
#
#   Evaluación del desempeño_AÑO 2025_INTERPRETACION  \
# 0                                             Alto
# 1                                             Alto
# 2                                             Alto
# 3                                             Alto
# 4                                             Alto
#
#   Evaluación del desempeño_AÑO 2024_OBJETIVO  \
# 0                                     0,6435
# 1                                0,623636364
# 2                                0,676416667
# 3                                0,747142857
# 4                                     0,7475
#
#   Evaluación del desempeño_AÑO 2024_COMPETENCIA  \
# 0                                   0,838055556
# 1                                   0,839141414
# 2                                   0,833333333
# 3                                   0,856746032
# 4                                   0,899479167
#
#   Evaluación del desempeño_AÑO 2024_RESULTADO  \
# 0                                     0,70782
# 1                                 0,694909091
# 2                                 0,723841667
# 3                                 0,782071429
# 4                                   0,7950875
#
#   Evaluación del desempeño_AÑO 2024_INTERPRETACION  \
# 0                                            Medio
# 1                                            Medio
# 2                                            Medio
# 3                                             Alto
# 4                                             Alto
#
#   Evaluación del desempeño_AÑO 2023_OBJETIVO  \
# 0                                0,699578571
# 1                                   0,724494
# 2                                0,707671818
# 3                                     0,6626
# 4                                 0,78424375
#
#   Evaluación del desempeño_AÑO 2023_COMPETENCIA  \
# 0                                   0,844571429
# 1                                        0,8648
# 2                                   0,855636364
# 3                                        0,9076
# 4                                         0,862
#
#   Evaluación del desempeño_AÑO 2023_RESULTADO  \
# 0                                 0,743076429
# 1                                   0,7658858
# 2                                 0,751815636
# 3                                      0,7361
# 4                                 0,811208125
#
#   Evaluación del desempeño_AÑO 2023_INTERPRETACION  \
# 0                                            Medio
# 1                                             Alto
# 2                                             Alto
# 3                                            Medio
# 4                                             Alto
#
#   Evaluación del desempeño_AÑO 2022_OBJETIVO  \
# 0                                      0,837
# 1                                0,671465909
# 2                                0,856689583
# 3                                    0,80725
# 4                                0,877857143
#
#   Evaluación del desempeño_AÑO 2022_COMPETENCIA  \
# 0                                        0,8668
# 1                                   0,809636364
# 2                                   0,788166667
# 3                                        0,7764
# 4                                   0,835428571
#
#   Evaluación del desempeño_AÑO 2022_RESULTADO  \
# 0                                     0,84594
# 1                                 0,712917045
# 2                                 0,836132708
# 3                                    0,797995
# 4                                 0,865128571
#
#   Evaluación del desempeño_AÑO 2022_INTERPRETACION  \
# 0                                             Alto
# 1                                            Medio
# 2                                             Alto
# 3                                             Alto
# 4                                             Alto
#
#   Evaluación del desempeño_AÑO 2021_OBJETIVO  \
# 0                                    0,90875
# 1                                0,854166667
# 2                                     0,8325
# 3                                     0,8025
# 4                                    0,86375
#
#   Evaluación del desempeño_AÑO 2021_COMPETENCIA  \
# 0                                   0,882986111
# 1                                   0,865509259
# 2                                   0,833912037
# 3                                   0,887152778
# 4                                   0,867708333
#
#   Evaluación del desempeño_AÑO 2021_RESULTADO  \
# 0                                 0,895868056
# 1                                 0,859837963
# 2                                 0,833206019
# 3                                 0,844826389
# 4                                 0,865729167
#
#   Evaluación del desempeño_AÑO 2021_INTERPRETACION  \
# 0                                             Alto
# 1                                             Alto
# 2                                             Alto
# 3                                             Alto
# 4                                             Alto
#
#   Evaluación del desempeño_AÑO 2020_OBJETIVO  \
# 0                                     0,8515
# 1                                0,841818182
# 2                                0,943333333
# 3                                0,921111111
# 4                                    0,91375
#
#   Evaluación del desempeño_AÑO 2020_COMPETENCIA  \
# 0                                   0,859861111
# 1                                   0,864646465
# 2                                   0,934606481
# 3                                   0,955092593
# 4                                   0,903472222
#
#   Evaluación del desempeño_AÑO 2020_RESULTADO  \
# 0                                 0,855680556
# 1                                 0,853232323
# 2                                 0,938969907
# 3                                 0,938101852
# 4                                 0,908611111
#
#   Evaluación del desempeño_AÑO 2020_INTERPRETACION  \
# 0                                             Alto
# 1                                             Alto
# 2                                         Muy alto
# 3                                         Muy alto
# 4                                         Muy alto
#
#   Engagement_AÑO 2025_AMBIENTE LABORAL Engagement_AÑO 2025_COMPROMISO  \
# 0                          0,963690476                              1
# 1                          0,840530303                    0,867424242
# 2                          0,843402778                    0,892361111
# 3                            0,8921875                    0,885416667
# 4                          0,969270833                    0,963541667
#
#   Engagement_AÑO 2025_INTERPRETACION
# 0                           Muy alto
# 1                              Medio
# 2                              Medio
# 3                               Alto
# 4                           Muy alto

# %%
# Validar el numero de filas y columnas del DataFrame
df.shape
# Out:
# (273, 61)

# %% [markdown]
# #### 5.2.1 Validación de valores faltantes y selección de unidades de análisis
#
# Se realiza una revisión inicial de los valores faltantes del conjunto de datos para identificar posibles limitaciones en la información disponible. Para garantizar la comparabilidad entre las unidades analizadas y considerando la disponibilidad de información en las dimensiones de Riesgo Psicosocial, Desempeño y Engagement, el análisis se concentrará en las unidades de tipo **Agencia** y **PDA**. Las unidades correspondientes a **Dirección General** y **Regional** se excluyen del análisis de clusterización.

# %%
# Distribución de unidades por tipo
df['TIPO'].value_counts()
# Out:
# TIPO
# Agencia              121
# Dirección general     74
# PDA                   65
# Regional              13
# Name: count, dtype: int64

# %%
# Validación de valores faltantes
resumen_nulos = pd.DataFrame({
    'Valores faltantes': df.isna().sum(),
    'Porcentaje (%)': (df.isna().mean() * 100).round(2)
})

resumen_nulos[resumen_nulos['Valores faltantes'] > 0].sort_values(
    'Porcentaje (%)',
    ascending=False
)
# Out:
#                                                     Valores faltantes  \
# Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo...                 67
# Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo alto                     67
# Riesgo psicosocial_AÑO 2023_EXTRABORALES_Sin ri...                 67
# Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo...                 67
# Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo...                 67
# Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo...                 67
# Riesgo psicosocial_AÑO 2023_INTRALABORALES_Sin ...                 67
# Riesgo psicosocial_AÑO 2023_INTRALABORALES_Ries...                 67
# Riesgo psicosocial_AÑO 2023_INTRALABORALES_Ries...                 67
# Riesgo psicosocial_AÑO 2023_INTRALABORALES_Ries...                 67
# Riesgo psicosocial_AÑO 2023_INTRALABORALES_Ries...                 67
# Riesgo psicosocial_AÑO 2023_ESTRÉS_Sin riesgo                      67
# Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo bajo                     67
# Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo medio                    67
# Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo muy alto                 67
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto                     52
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy alto                 52
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin ri...                 52
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...                 52
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...                 52
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo                     52
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo                      52
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...                 52
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...                 52
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio                    52
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...                 52
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...                 52
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...                 52
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...                 52
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin ...                 52
# Evaluación del desempeño_AÑO 2022_RESULTADO                        21
# Evaluación del desempeño_AÑO 2022_COMPETENCIA                      21
# Evaluación del desempeño_AÑO 2022_OBJETIVO                         21
# Evaluación del desempeño_AÑO 2021_COMPETENCIA                      21
# Evaluación del desempeño_AÑO 2021_RESULTADO                        21
# Evaluación del desempeño_AÑO 2020_OBJETIVO                         21
# Evaluación del desempeño_AÑO 2021_INTERPRETACION                   21
# Evaluación del desempeño_AÑO 2020_COMPETENCIA                      21
# Evaluación del desempeño_AÑO 2020_RESULTADO                        21
# Evaluación del desempeño_AÑO 2020_INTERPRETACION                   21
# Evaluación del desempeño_AÑO 2021_OBJETIVO                         21
# Evaluación del desempeño_AÑO 2022_INTERPRETACION                   21
# Engagement_AÑO 2025_INTERPRETACION                                  6
# Engagement_AÑO 2025_AMBIENTE LABORAL                                5
# Engagement_AÑO 2025_COMPROMISO                                      5
# Evaluación del desempeño_AÑO 2023_INTERPRETACION                    4
# Evaluación del desempeño_AÑO 2023_RESULTADO                         4
# Evaluación del desempeño_AÑO 2023_OBJETIVO                          4
# Evaluación del desempeño_AÑO 2024_INTERPRETACION                    4
# Evaluación del desempeño_AÑO 2024_RESULTADO                         4
# Evaluación del desempeño_AÑO 2024_COMPETENCIA                       4
# Evaluación del desempeño_AÑO 2024_OBJETIVO                          4
# Evaluación del desempeño_AÑO 2023_COMPETENCIA                       4
#
#                                                     Porcentaje (%)
# Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo...           24.54
# Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo alto               24.54
# Riesgo psicosocial_AÑO 2023_EXTRABORALES_Sin ri...           24.54
# Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo...           24.54
# Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo...           24.54
# Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo...           24.54
# Riesgo psicosocial_AÑO 2023_INTRALABORALES_Sin ...           24.54
# Riesgo psicosocial_AÑO 2023_INTRALABORALES_Ries...           24.54
# Riesgo psicosocial_AÑO 2023_INTRALABORALES_Ries...           24.54
# Riesgo psicosocial_AÑO 2023_INTRALABORALES_Ries...           24.54
# Riesgo psicosocial_AÑO 2023_INTRALABORALES_Ries...           24.54
# Riesgo psicosocial_AÑO 2023_ESTRÉS_Sin riesgo                24.54
# Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo bajo               24.54
# Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo medio              24.54
# Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo muy alto           24.54
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto               19.05
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy alto           19.05
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin ri...           19.05
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...           19.05
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...           19.05
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo               19.05
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo                19.05
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...           19.05
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...           19.05
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio              19.05
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...           19.05
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...           19.05
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...           19.05
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...           19.05
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin ...           19.05
# Evaluación del desempeño_AÑO 2022_RESULTADO                   7.69
# Evaluación del desempeño_AÑO 2022_COMPETENCIA                 7.69
# Evaluación del desempeño_AÑO 2022_OBJETIVO                    7.69
# Evaluación del desempeño_AÑO 2021_COMPETENCIA                 7.69
# Evaluación del desempeño_AÑO 2021_RESULTADO                   7.69
# Evaluación del desempeño_AÑO 2020_OBJETIVO                    7.69
# Evaluación del desempeño_AÑO 2021_INTERPRETACION              7.69
# Evaluación del desempeño_AÑO 2020_COMPETENCIA                 7.69
# Evaluación del desempeño_AÑO 2020_RESULTADO                   7.69
# Evaluación del desempeño_AÑO 2020_INTERPRETACION              7.69
# Evaluación del desempeño_AÑO 2021_OBJETIVO                    7.69
# Evaluación del desempeño_AÑO 2022_INTERPRETACION              7.69
# Engagement_AÑO 2025_INTERPRETACION                            2.20
# Engagement_AÑO 2025_AMBIENTE LABORAL                          1.83
# Engagement_AÑO 2025_COMPROMISO                                1.83
# Evaluación del desempeño_AÑO 2023_INTERPRETACION              1.47
# Evaluación del desempeño_AÑO 2023_RESULTADO                   1.47
# Evaluación del desempeño_AÑO 2023_OBJETIVO                    1.47
# Evaluación del desempeño_AÑO 2024_INTERPRETACION              1.47
# Evaluación del desempeño_AÑO 2024_RESULTADO                   1.47
# Evaluación del desempeño_AÑO 2024_COMPETENCIA                 1.47
# Evaluación del desempeño_AÑO 2024_OBJETIVO                    1.47
# Evaluación del desempeño_AÑO 2023_COMPETENCIA                 1.47

# %%
# Seleccionar únicamente Agencias y PDA
df_modelo = df[df['TIPO'].isin(['Agencia', 'PDA'])].copy()

# Verificar dimensiones
print(f"Registros iniciales: {len(df)}")
print(f"Registros para el análisis: {len(df_modelo)}")

print("\nDistribución de unidades:")
print(df_modelo['TIPO'].value_counts())

print ("----" * 20)
# Verificar tipos incluidos en el dataset de análisis
df_modelo['TIPO'].unique()
# Out:
# Registros iniciales: 273
# Registros para el análisis: 186
#
# Distribución de unidades:
# TIPO
# Agencia    121
# PDA         65
# Name: count, dtype: int64
# --------------------------------------------------------------------------------
# <StringArray>
# ['PDA', 'Agencia']
# Length: 2, dtype: str

# %% [markdown]
# ### 5.3 Transformación y ajuste de tipos de datos

# %% [markdown]
# Durante la exploración inicial se identificó que varias variables cuantitativas fueron cargadas como texto (`string`), a pesar de contener valores numéricos. Esto se debe principalmente al formato utilizado para representar los decimales. También se identificó que la variable `APERTURA` corresponde a una fecha almacenada como número serial de Excel. Se realizará la conversión de estas variables a sus tipos de datos correspondientes, manteniendo como variables categóricas aquellas que representan identificadores, tipos de unidad, regionales e interpretaciones.

# %%
# Variables que deben permanecer como categóricas
variables_categoricas = [
    'REGIONAL',
    'CODIGO UNIDAD',
    'TIPO'
]

# Variables de interpretación
variables_interpretacion = [
    col for col in df.columns 
    if 'INTERPRETACION' in col
]

variables_categoricas = variables_categoricas + variables_interpretacion

# Variables candidatas a conversión numérica
variables_numericas = [
    col for col in df.columns 
    if col not in variables_categoricas + ['APERTURA']
]

len(variables_numericas)

# Convertir variables numéricas de texto a formato numérico
for col in variables_numericas:
    df_modelo[col] = pd.to_numeric(
        df[col].astype(str).str.replace(',', '.', regex=False),
        errors='coerce'
    )

# Convertir APERTURA de número serial de Excel a fecha
df_modelo['APERTURA'] = pd.to_datetime(
    df_modelo['APERTURA'],
    unit='D',
    origin='1899-12-30'
)
    
# Información general del conjunto de datos
df_modelo.info()

# Visualización de los primeros registros
df_modelo.head()
# Out:
# <class 'pandas.DataFrame'>
# Index: 186 entries, 1 to 272
# Data columns (total 61 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   REGIONAL                                                    186 non-null    str
#  1   CODIGO UNIDAD                                               186 non-null    str
#  2   TIPO                                                        186 non-null    str
#  3   APERTURA                                                    186 non-null    datetime64[s]
#  4   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy alto          186 non-null    float64
#  5   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto              186 non-null    float64
#  6   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio             186 non-null    float64
#  7   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo              186 non-null    float64
#  8   Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo               186 non-null    float64
#  9   Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo muy alto  186 non-null    float64
#  10  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo alto      186 non-null    float64
#  11  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo medio     186 non-null    float64
#  12  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo bajo      186 non-null    float64
#  13  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin riesgo       186 non-null    float64
#  14  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo muy alto    186 non-null    float64
#  15  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo alto        186 non-null    float64
#  16  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo medio       186 non-null    float64
#  17  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo bajo        186 non-null    float64
#  18  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin riesgo         186 non-null    float64
#  19  Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo muy alto          171 non-null    float64
#  20  Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo alto              171 non-null    float64
#  21  Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo medio             171 non-null    float64
#  22  Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo bajo              171 non-null    float64
#  23  Riesgo psicosocial_AÑO 2023_ESTRÉS_Sin riesgo               171 non-null    float64
#  24  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo muy alto  171 non-null    float64
#  25  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo alto      171 non-null    float64
#  26  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo medio     171 non-null    float64
#  27  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo bajo      171 non-null    float64
#  28  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Sin riesgo       171 non-null    float64
#  29  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo muy alto    171 non-null    float64
#  30  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo alto        171 non-null    float64
#  31  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo medio       171 non-null    float64
#  32  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo bajo        171 non-null    float64
#  33  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Sin riesgo         171 non-null    float64
#  34  Evaluación del desempeño_AÑO 2025_OBJETIVO                  186 non-null    float64
#  35  Evaluación del desempeño_AÑO 2025_COMPETENCIA               186 non-null    float64
#  36  Evaluación del desempeño_AÑO 2025_RESULTADO                 186 non-null    float64
#  37  Evaluación del desempeño_AÑO 2025_INTERPRETACION            186 non-null    str
#  38  Evaluación del desempeño_AÑO 2024_OBJETIVO                  186 non-null    float64
#  39  Evaluación del desempeño_AÑO 2024_COMPETENCIA               186 non-null    float64
#  40  Evaluación del desempeño_AÑO 2024_RESULTADO                 186 non-null    float64
#  41  Evaluación del desempeño_AÑO 2024_INTERPRETACION            186 non-null    str
#  42  Evaluación del desempeño_AÑO 2023_OBJETIVO                  186 non-null    float64
#  43  Evaluación del desempeño_AÑO 2023_COMPETENCIA               186 non-null    float64
#  44  Evaluación del desempeño_AÑO 2023_RESULTADO                 186 non-null    float64
#  45  Evaluación del desempeño_AÑO 2023_INTERPRETACION            186 non-null    str
#  46  Evaluación del desempeño_AÑO 2022_OBJETIVO                  182 non-null    float64
#  47  Evaluación del desempeño_AÑO 2022_COMPETENCIA               182 non-null    float64
#  48  Evaluación del desempeño_AÑO 2022_RESULTADO                 182 non-null    float64
#  49  Evaluación del desempeño_AÑO 2022_INTERPRETACION            182 non-null    str
#  50  Evaluación del desempeño_AÑO 2021_OBJETIVO                  182 non-null    float64
#  51  Evaluación del desempeño_AÑO 2021_COMPETENCIA               182 non-null    float64
#  52  Evaluación del desempeño_AÑO 2021_RESULTADO                 182 non-null    float64
#  53  Evaluación del desempeño_AÑO 2021_INTERPRETACION            182 non-null    str
#  54  Evaluación del desempeño_AÑO 2020_OBJETIVO                  182 non-null    float64
#  55  Evaluación del desempeño_AÑO 2020_COMPETENCIA               182 non-null    float64
#  56  Evaluación del desempeño_AÑO 2020_RESULTADO                 182 non-null    float64
#  57  Evaluación del desempeño_AÑO 2020_INTERPRETACION            182 non-null    str
#  58  Engagement_AÑO 2025_AMBIENTE LABORAL                        186 non-null    float64
#  59  Engagement_AÑO 2025_COMPROMISO                              186 non-null    float64
#  60  Engagement_AÑO 2025_INTERPRETACION                          186 non-null    str
# dtypes: datetime64[s](1), float64(50), str(10)
# memory usage: 90.1 KB
#   REGIONAL CODIGO UNIDAD TIPO   APERTURA  \
# 1    CAUCA  A411243       PDA 2008-04-01
# 2    CAUCA  A411242       PDA 2009-08-01
# 3    CAUCA  A411221       PDA 2019-07-15
# 4    CAUCA  A411241       PDA 2008-04-01
# 5    CAUCA  A411231       PDA 2009-03-01
#
#    Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy alto  \
# 1                                           0.222222
# 2                                           0.444444
# 3                                           0.333333
# 4                                           0.125000
# 5                                           0.090909
#
#    Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto  \
# 1                                        0.222222
# 2                                        0.333333
# 3                                        0.166667
# 4                                        0.500000
# 5                                        0.181818
#
#    Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio  \
# 1                                         0.333333
# 2                                         0.222222
# 3                                         0.500000
# 4                                         0.000000
# 5                                         0.363636
#
#    Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo  \
# 1                                        0.222222
# 2                                        0.000000
# 3                                        0.000000
# 4                                        0.000000
# 5                                        0.272727
#
#    Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo  \
# 1                                       0.000000
# 2                                       0.000000
# 3                                       0.000000
# 4                                       0.375000
# 5                                       0.090909
#
#    Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo muy alto  \
# 1                                           0.222222
# 2                                           0.222222
# 3                                           0.000000
# 4                                           0.000000
# 5                                           0.090909
#
#    Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo alto  \
# 1                                           0.222222
# 2                                           0.222222
# 3                                           0.000000
# 4                                           0.000000
# 5                                           0.181818
#
#    Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo medio  \
# 1                                           0.333333
# 2                                           0.111111
# 3                                           0.666667
# 4                                           0.250000
# 5                                           0.000000
#
#    Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo bajo  \
# 1                                           0.111111
# 2                                           0.444444
# 3                                           0.166667
# 4                                           0.250000
# 5                                           0.454545
#
#    Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin riesgo  \
# 1                                           0.111111
# 2                                           0.000000
# 3                                           0.166667
# 4                                           0.500000
# 5                                           0.272727
#
#    Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo muy alto  \
# 1                                           0.111111
# 2                                           0.111111
# 3                                           0.000000
# 4                                           0.125000
# 5                                           0.090909
#
#    Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo alto  \
# 1                                           0.222222
# 2                                           0.333333
# 3                                           0.666667
# 4                                           0.250000
# 5                                           0.181818
#
#    Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo medio  \
# 1                                           0.555556
# 2                                           0.333333
# 3                                           0.333333
# 4                                           0.125000
# 5                                           0.272727
#
#    Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo bajo  \
# 1                                           0.111111
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.000000
# 5                                           0.363636
#
#    Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin riesgo  \
# 1                                           0.000000
# 2                                           0.222222
# 3                                           0.000000
# 4                                           0.500000
# 5                                           0.090909
#
#    Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo muy alto  \
# 1                                           0.363636
# 2                                           0.416667
# 3                                           0.666667
# 4                                           0.142857
# 5                                           0.416667
#
#    Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo alto  \
# 1                                        0.181818
# 2                                        0.166667
# 3                                        0.000000
# 4                                        0.285714
# 5                                        0.166667
#
#    Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo medio  \
# 1                                         0.000000
# 2                                         0.166667
# 3                                         0.111111
# 4                                         0.285714
# 5                                         0.083333
#
#    Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo bajo  \
# 1                                        0.272727
# 2                                        0.250000
# 3                                        0.111111
# 4                                        0.285714
# 5                                        0.083333
#
#    Riesgo psicosocial_AÑO 2023_ESTRÉS_Sin riesgo  \
# 1                                       0.181818
# 2                                       0.000000
# 3                                       0.111111
# 4                                       0.000000
# 5                                       0.250000
#
#    Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo muy alto  \
# 1                                           0.090909
# 2                                           0.083333
# 3                                           0.222222
# 4                                           0.000000
# 5                                           0.083333
#
#    Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo alto  \
# 1                                           0.090909
# 2                                           0.333333
# 3                                           0.222222
# 4                                           0.000000
# 5                                           0.166667
#
#    Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo medio  \
# 1                                           0.181818
# 2                                           0.333333
# 3                                           0.555556
# 4                                           0.142857
# 5                                           0.333333
#
#    Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo bajo  \
# 1                                           0.454545
# 2                                           0.166667
# 3                                           0.000000
# 4                                           0.571429
# 5                                           0.166667
#
#    Riesgo psicosocial_AÑO 2023_INTRALABORALES_Sin riesgo  \
# 1                                           0.181818
# 2                                           0.083333
# 3                                           0.000000
# 4                                           0.285714
# 5                                           0.250000
#
#    Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo muy alto  \
# 1                                           0.181818
# 2                                           0.250000
# 3                                           0.444444
# 4                                           0.142857
# 5                                           0.166667
#
#    Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo alto  \
# 1                                           0.090909
# 2                                           0.250000
# 3                                           0.333333
# 4                                           0.142857
# 5                                           0.083333
#
#    Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo medio  \
# 1                                           0.363636
# 2                                           0.083333
# 3                                           0.222222
# 4                                           0.000000
# 5                                           0.583333
#
#    Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo bajo  \
# 1                                           0.363636
# 2                                           0.166667
# 3                                           0.000000
# 4                                           0.285714
# 5                                           0.083333
#
#    Riesgo psicosocial_AÑO 2023_EXTRABORALES_Sin riesgo  \
# 1                                           0.000000
# 2                                           0.250000
# 3                                           0.000000
# 4                                           0.428571
# 5                                           0.083333
#
#    Evaluación del desempeño_AÑO 2025_OBJETIVO  \
# 1                                    0.807467
# 2                                    0.835373
# 3                                    0.821963
# 4                                    0.879329
# 5                                    0.888977
#
#    Evaluación del desempeño_AÑO 2025_COMPETENCIA  \
# 1                                       0.847273
# 2                                       0.865455
# 3                                       0.867857
# 4                                       0.879107
# 5                                       0.887033
#
#    Evaluación del desempeño_AÑO 2025_RESULTADO  \
# 1                                     0.819409
# 2                                     0.844397
# 3                                     0.835731
# 4                                     0.879262
# 5                                     0.888394
#
#   Evaluación del desempeño_AÑO 2025_INTERPRETACION  \
# 1                                             Alto
# 2                                             Alto
# 3                                             Alto
# 4                                             Alto
# 5                                             Alto
#
#    Evaluación del desempeño_AÑO 2024_OBJETIVO  \
# 1                                    0.623636
# 2                                    0.676417
# 3                                    0.747143
# 4                                    0.747500
# 5                                    0.770357
#
#    Evaluación del desempeño_AÑO 2024_COMPETENCIA  \
# 1                                       0.839141
# 2                                       0.833333
# 3                                       0.856746
# 4                                       0.899479
# 5                                       0.935516
#
#    Evaluación del desempeño_AÑO 2024_RESULTADO  \
# 1                                     0.694909
# 2                                     0.723842
# 3                                     0.782071
# 4                                     0.795087
# 5                                     0.824914
#
#   Evaluación del desempeño_AÑO 2024_INTERPRETACION  \
# 1                                            Medio
# 2                                            Medio
# 3                                             Alto
# 4                                             Alto
# 5                                             Alto
#
#    Evaluación del desempeño_AÑO 2023_OBJETIVO  \
# 1                                    0.724494
# 2                                    0.707672
# 3                                    0.662600
# 4                                    0.784244
# 5                                    0.579346
#
#    Evaluación del desempeño_AÑO 2023_COMPETENCIA  \
# 1                                       0.864800
# 2                                       0.855636
# 3                                       0.907600
# 4                                       0.862000
# 5                                       0.820364
#
#    Evaluación del desempeño_AÑO 2023_RESULTADO  \
# 1                                     0.765886
# 2                                     0.751816
# 3                                     0.736100
# 4                                     0.811208
# 5                                     0.652524
#
#   Evaluación del desempeño_AÑO 2023_INTERPRETACION  \
# 1                                             Alto
# 2                                             Alto
# 3                                            Medio
# 4                                             Alto
# 5                                            Medio
#
#    Evaluación del desempeño_AÑO 2022_OBJETIVO  \
# 1                                    0.671466
# 2                                    0.856690
# 3                                    0.807250
# 4                                    0.877857
# 5                                    0.831989
#
#    Evaluación del desempeño_AÑO 2022_COMPETENCIA  \
# 1                                       0.809636
# 2                                       0.788167
# 3                                       0.776400
# 4                                       0.835429
# 5                                       0.857273
#
#    Evaluación del desempeño_AÑO 2022_RESULTADO  \
# 1                                     0.712917
# 2                                     0.836133
# 3                                     0.797995
# 4                                     0.865129
# 5                                     0.839574
#
#   Evaluación del desempeño_AÑO 2022_INTERPRETACION  \
# 1                                            Medio
# 2                                             Alto
# 3                                             Alto
# 4                                             Alto
# 5                                             Alto
#
#    Evaluación del desempeño_AÑO 2021_OBJETIVO  \
# 1                                    0.854167
# 2                                    0.832500
# 3                                    0.802500
# 4                                    0.863750
# 5                                    0.862667
#
#    Evaluación del desempeño_AÑO 2021_COMPETENCIA  \
# 1                                       0.865509
# 2                                       0.833912
# 3                                       0.887153
# 4                                       0.867708
# 5                                       0.853241
#
#    Evaluación del desempeño_AÑO 2021_RESULTADO  \
# 1                                     0.859838
# 2                                     0.833206
# 3                                     0.844826
# 4                                     0.865729
# 5                                     0.857954
#
#   Evaluación del desempeño_AÑO 2021_INTERPRETACION  \
# 1                                             Alto
# 2                                             Alto
# 3                                             Alto
# 4                                             Alto
# 5                                             Alto
#
#    Evaluación del desempeño_AÑO 2020_OBJETIVO  \
# 1                                    0.841818
# 2                                    0.943333
# 3                                    0.921111
# 4                                    0.913750
# 5                                    0.847500
#
#    Evaluación del desempeño_AÑO 2020_COMPETENCIA  \
# 1                                       0.864646
# 2                                       0.934606
# 3                                       0.955093
# 4                                       0.903472
# 5                                       0.869792
#
#    Evaluación del desempeño_AÑO 2020_RESULTADO  \
# 1                                     0.853232
# 2                                     0.938970
# 3                                     0.938102
# 4                                     0.908611
# 5                                     0.858646
#
#   Evaluación del desempeño_AÑO 2020_INTERPRETACION  \
# 1                                             Alto
# 2                                         Muy alto
# 3                                         Muy alto
# 4                                         Muy alto
# 5                                             Alto
#
#    Engagement_AÑO 2025_AMBIENTE LABORAL  Engagement_AÑO 2025_COMPROMISO  \
# 1                              0.840530                        0.867424
# 2                              0.843403                        0.892361
# 3                              0.892188                        0.885417
# 4                              0.969271                        0.963542
# 5                              0.947917                        0.934524
#
#   Engagement_AÑO 2025_INTERPRETACION
# 1                              Medio
# 2                              Medio
# 3                               Alto
# 4                           Muy alto
# 5                               Alto

# %%
# Validar el numero de filas y columnas del DataFrame
df_modelo.shape
# Out:
# (186, 61)

# %% [markdown]
# **Resumen:** Se identificaron valores faltantes en algunas variables, principalmente asociados a unidades que no cuentan con determinadas mediciones. Para garantizar la comparabilidad de las unidades y reducir el impacto de la ausencia de información, se definió como población de análisis las **186 unidades operativas correspondientes a 121 Agencias y 65 PDA**. Estas unidades serán utilizadas posteriormente en el análisis exploratorio y en el modelo de clusterización.

# %% [markdown]
# ### 5.4 Reducción y análisis de variables categóricas y numéricas

# %% [markdown]
# Se realiza una caracterización general de las variables del conjunto de datos, diferenciando entre variables categóricas y numéricas. Este análisis permite conocer la distribución de las principales variables y establecer una base para la selección de los indicadores que posteriormente serán utilizados en el modelo de clusterización.
#
# Adicionalmente se realizará la identificación de relaciones y posibles redundancias entre las variables que representan las dimensiones de Riesgo Psicosocial, Evaluación del Desempeño y Engagement. A partir de este análisis se definirán grupos de variables y criterios para construir indicadores representativos que reduzcan la dimensionalidad del conjunto de datos y faciliten posteriormente el proceso de clusterización.

# %%
# Identificar variables categóricas y numéricas
variables_categoricas = df_modelo.select_dtypes(include=['str', 'object', 'category']).columns.tolist()
variables_numericas = df_modelo.select_dtypes(include=['number']).columns.tolist()

print(f"Variables categóricas: {len(variables_categoricas)}")
print(f"Variables numéricas: {len(variables_numericas)}")

print ("----"*20)

print("Variables categóricas:")
for variable in variables_categoricas:
    print(f"- {variable}")

print("\nVariables numéricas:")
for variable in variables_numericas:
    print(f"- {variable}")
# Out:
# Variables categóricas: 10
# Variables numéricas: 50
# --------------------------------------------------------------------------------
# Variables categóricas:
# - REGIONAL
# - CODIGO UNIDAD
# - TIPO
# - Evaluación del desempeño_AÑO 2025_INTERPRETACION
# - Evaluación del desempeño_AÑO 2024_INTERPRETACION
# - Evaluación del desempeño_AÑO 2023_INTERPRETACION
# - Evaluación del desempeño_AÑO 2022_INTERPRETACION
# - Evaluación del desempeño_AÑO 2021_INTERPRETACION
# - Evaluación del desempeño_AÑO 2020_INTERPRETACION
# - Engagement_AÑO 2025_INTERPRETACION
#
# Variables numéricas:
# - Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy alto
# - Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto
# - Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio
# - Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo
# - Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo
# - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo muy alto
# - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo alto
# - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo medio
# - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo bajo
# - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin riesgo
# - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo muy alto
# - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo alto
# - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo medio
# - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo bajo
# - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin riesgo
# - Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo muy alto
# - Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo alto
# - Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo medio
# - Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo bajo
# - Riesgo psicosocial_AÑO 2023_ESTRÉS_Sin riesgo
# - Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo muy alto
# - Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo alto
# - Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo medio
# - Riesgo psicosocial_AÑO 2023_INTRALABORALES_Riesgo bajo
# - Riesgo psicosocial_AÑO 2023_INTRALABORALES_Sin riesgo
# - Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo muy alto
# - Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo alto
# - Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo medio
# - Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesgo bajo
# - Riesgo psicosocial_AÑO 2023_EXTRABORALES_Sin riesgo
# - Evaluación del desempeño_AÑO 2025_OBJETIVO
# - Evaluación del desempeño_AÑO 2025_COMPETENCIA
# - Evaluación del desempeño_AÑO 2025_RESULTADO
# - Evaluación del desempeño_AÑO 2024_OBJETIVO
# - Evaluación del desempeño_AÑO 2024_COMPETENCIA
# - Evaluación del desempeño_AÑO 2024_RESULTADO
# - Evaluación del desempeño_AÑO 2023_OBJETIVO
# - Evaluación del desempeño_AÑO 2023_COMPETENCIA
# - Evaluación del desempeño_AÑO 2023_RESULTADO
# - Evaluación del desempeño_AÑO 2022_OBJETIVO
# - Evaluación del desempeño_AÑO 2022_COMPETENCIA
# - Evaluación del desempeño_AÑO 2022_RESULTADO
# - Evaluación del desempeño_AÑO 2021_OBJETIVO
# - Evaluación del desempeño_AÑO 2021_COMPETENCIA
# - Evaluación del desempeño_AÑO 2021_RESULTADO
# - Evaluación del desempeño_AÑO 2020_OBJETIVO
# - Evaluación del desempeño_AÑO 2020_COMPETENCIA
# - Evaluación del desempeño_AÑO 2020_RESULTADO
# - Engagement_AÑO 2025_AMBIENTE LABORAL
# - Engagement_AÑO 2025_COMPROMISO

# %%
# Resumen de variables numéricas
resumen_numericas = pd.DataFrame({
    'Variable': variables_numericas,
    'Mínimo': df_modelo[variables_numericas].min().values,
    'Máximo': df_modelo[variables_numericas].max().values,
    'Media': df_modelo[variables_numericas].mean().values,
    'Mediana': df_modelo[variables_numericas].median().values,
    'Valores faltantes': df_modelo[variables_numericas].isna().sum().values
})

resumen_numericas
# Out:
#                                              Variable    Mínimo    Máximo  \
# 0   Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy ...  0.000000  0.750000
# 1      Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto  0.000000  0.500000
# 2     Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio  0.000000  0.600000
# 3      Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo  0.000000  0.571429
# 4       Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo  0.000000  0.615385
# 5   Riesgo psicosocial_AÑO 2025_INTRALABORALES_Rie...  0.000000  0.625000
# 6   Riesgo psicosocial_AÑO 2025_INTRALABORALES_Rie...  0.000000  0.555556
# 7   Riesgo psicosocial_AÑO 2025_INTRALABORALES_Rie...  0.000000  0.750000
# 8   Riesgo psicosocial_AÑO 2025_INTRALABORALES_Rie...  0.000000  0.666667
# 9   Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin...  0.000000  0.666667
# 10  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesg...  0.000000  0.750000
# 11  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesg...  0.000000  0.666667
# 12  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesg...  0.000000  0.555556
# 13  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesg...  0.000000  0.375000
# 14  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin r...  0.000000  0.714286
# 15  Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo muy ...  0.000000  0.666667
# 16     Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo alto  0.000000  1.000000
# 17    Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo medio  0.000000  1.000000
# 18     Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo bajo  0.000000  1.000000
# 19      Riesgo psicosocial_AÑO 2023_ESTRÉS_Sin riesgo  0.000000  0.666667
# 20  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Rie...  0.000000  0.705882
# 21  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Rie...  0.000000  0.384615
# 22  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Rie...  0.000000  1.000000
# 23  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Rie...  0.000000  0.666667
# 24  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Sin...  0.000000  1.000000
# 25  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesg...  0.000000  0.600000
# 26  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesg...  0.000000  1.000000
# 27  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesg...  0.000000  0.583333
# 28  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesg...  0.000000  0.666667
# 29  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Sin r...  0.000000  1.000000
# 30         Evaluación del desempeño_AÑO 2025_OBJETIVO  0.717086  0.966847
# 31      Evaluación del desempeño_AÑO 2025_COMPETENCIA  0.781071  0.993407
# 32        Evaluación del desempeño_AÑO 2025_RESULTADO  0.754400  0.956436
# 33         Evaluación del desempeño_AÑO 2024_OBJETIVO  0.428700  0.962222
# 34      Evaluación del desempeño_AÑO 2024_COMPETENCIA  0.767014  0.984815
# 35        Evaluación del desempeño_AÑO 2024_RESULTADO  0.551600  0.938321
# 36         Evaluación del desempeño_AÑO 2023_OBJETIVO  0.193667  1.000000
# 37      Evaluación del desempeño_AÑO 2023_COMPETENCIA  0.779250  0.989556
# 38        Evaluación del desempeño_AÑO 2023_RESULTADO  0.455863  0.970463
# 39         Evaluación del desempeño_AÑO 2022_OBJETIVO  0.489597  1.000000
# 40      Evaluación del desempeño_AÑO 2022_COMPETENCIA  0.566692  0.980667
# 41        Evaluación del desempeño_AÑO 2022_RESULTADO  0.582060  0.973900
# 42         Evaluación del desempeño_AÑO 2021_OBJETIVO  0.000000  1.000000
# 43      Evaluación del desempeño_AÑO 2021_COMPETENCIA  0.000000  1.000000
# 44        Evaluación del desempeño_AÑO 2021_RESULTADO  0.000000  1.000000
# 45         Evaluación del desempeño_AÑO 2020_OBJETIVO  0.000000  0.970417
# 46      Evaluación del desempeño_AÑO 2020_COMPETENCIA  0.000000  0.981151
# 47        Evaluación del desempeño_AÑO 2020_RESULTADO  0.000000  0.965909
# 48               Engagement_AÑO 2025_AMBIENTE LABORAL  0.663021  0.974537
# 49                     Engagement_AÑO 2025_COMPROMISO  0.629386  0.981481
#
#        Media   Mediana  Valores faltantes
# 0   0.301177  0.300000                  0
# 1   0.201255  0.200000                  0
# 2   0.168790  0.155048                  0
# 3   0.172006  0.153846                  0
# 4   0.156772  0.142857                  0
# 5   0.158916  0.142857                  0
# 6   0.186881  0.179144                  0
# 7   0.209583  0.200000                  0
# 8   0.210308  0.200000                  0
# 9   0.234312  0.200000                  0
# 10  0.136956  0.125000                  0
# 11  0.192779  0.181818                  0
# 12  0.213287  0.214286                  0
# 13  0.164409  0.166667                  0
# 14  0.292568  0.272727                  0
# 15  0.274966  0.263158                 15
# 16  0.188868  0.181818                 15
# 17  0.173620  0.157895                 15
# 18  0.184018  0.166667                 15
# 19  0.178528  0.166667                 15
# 20  0.104700  0.086957                 15
# 21  0.172693  0.166667                 15
# 22  0.214186  0.200000                 15
# 23  0.248727  0.250000                 15
# 24  0.259693  0.250000                 15
# 25  0.120067  0.105263                 15
# 26  0.192423  0.187500                 15
# 27  0.223752  0.222222                 15
# 28  0.176442  0.173913                 15
# 29  0.287317  0.272727                 15
# 30  0.810355  0.809399                  0
# 31  0.882500  0.884932                  0
# 32  0.832069  0.833067                  0
# 33  0.707995  0.729042                  0
# 34  0.869271  0.871203                  0
# 35  0.759142  0.769503                  0
# 36  0.696534  0.711685                  0
# 37  0.866597  0.864550                  0
# 38  0.754342  0.758031                  0
# 39  0.739414  0.741546                  4
# 40  0.849996  0.847661                  4
# 41  0.772981  0.777930                  4
# 42  0.780109  0.823765                  4
# 43  0.812533  0.847277                  4
# 44  0.796321  0.833157                  4
# 45  0.811437  0.856000                  4
# 46  0.834309  0.878446                  4
# 47  0.822873  0.865722                  4
# 48  0.867907  0.873272                  0
# 49  0.877591  0.885764                  0

# %% [markdown]
# #### 5.4.1 Caracterización de variables
#
# Se identifican las variables numéricas disponibles y se agrupan inicialmente de acuerdo con la dimensión y el concepto que representan. Esta clasificación permitirá diferenciar las variables asociadas a Riesgo Psicosocial, Evaluación del Desempeño y Engagement, y servirá como base para el análisis de correlaciones y la posterior construcción de indicadores.

# %%
# Identificar variables de Riesgo Psicosocial
variables_psicosocial = [
    col for col in df_modelo.columns
    if 'Riesgo psicosocial' in col
]

# Identificar variables de Evaluación del Desempeño
variables_desempeno = [
    col for col in df_modelo.columns
    if any(palabra in col.upper() for palabra in [
        'OBJETIVO',
        'COMPETENCIA',
        'RESULTADO'
    ])
]

# Identificar variables numéricas de Engagement
variables_engagement = [
    col for col in df_modelo.columns
    if 'Engagement' in col
    and 'INTERPRETACION' not in col.upper()
]

print(f"Variables de Riesgo Psicosocial: {len(variables_psicosocial)}")
print(f"Variables de Desempeño: {len(variables_desempeno)}")
print(f"Variables de Engagement: {len(variables_engagement)}")

print ("----"*20)

# Crear resumen de variables por dimensión
resumen_dimensiones = pd.DataFrame({
    'Dimensión': (
        ['Riesgo Psicosocial'] * len(variables_psicosocial) +
        ['Desempeño'] * len(variables_desempeno) +
        ['Engagement'] * len(variables_engagement)
    ),
    'Variable': (
        variables_psicosocial +
        variables_desempeno +
        variables_engagement
    )
})

resumen_dimensiones
# Out:
# Variables de Riesgo Psicosocial: 30
# Variables de Desempeño: 18
# Variables de Engagement: 2
# --------------------------------------------------------------------------------
#              Dimensión                                           Variable
# 0   Riesgo Psicosocial  Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy ...
# 1   Riesgo Psicosocial     Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto
# 2   Riesgo Psicosocial    Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio
# 3   Riesgo Psicosocial     Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo
# 4   Riesgo Psicosocial      Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo
# 5   Riesgo Psicosocial  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Rie...
# 6   Riesgo Psicosocial  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Rie...
# 7   Riesgo Psicosocial  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Rie...
# 8   Riesgo Psicosocial  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Rie...
# 9   Riesgo Psicosocial  Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin...
# 10  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesg...
# 11  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesg...
# 12  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesg...
# 13  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesg...
# 14  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin r...
# 15  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo muy ...
# 16  Riesgo Psicosocial     Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo alto
# 17  Riesgo Psicosocial    Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo medio
# 18  Riesgo Psicosocial     Riesgo psicosocial_AÑO 2023_ESTRÉS_Riesgo bajo
# 19  Riesgo Psicosocial      Riesgo psicosocial_AÑO 2023_ESTRÉS_Sin riesgo
# 20  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Rie...
# 21  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Rie...
# 22  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Rie...
# 23  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Rie...
# 24  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2023_INTRALABORALES_Sin...
# 25  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesg...
# 26  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesg...
# 27  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesg...
# 28  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Riesg...
# 29  Riesgo Psicosocial  Riesgo psicosocial_AÑO 2023_EXTRABORALES_Sin r...
# 30           Desempeño         Evaluación del desempeño_AÑO 2025_OBJETIVO
# 31           Desempeño      Evaluación del desempeño_AÑO 2025_COMPETENCIA
# 32           Desempeño        Evaluación del desempeño_AÑO 2025_RESULTADO
# 33           Desempeño         Evaluación del desempeño_AÑO 2024_OBJETIVO
# 34           Desempeño      Evaluación del desempeño_AÑO 2024_COMPETENCIA
# 35           Desempeño        Evaluación del desempeño_AÑO 2024_RESULTADO
# 36           Desempeño         Evaluación del desempeño_AÑO 2023_OBJETIVO
# 37           Desempeño      Evaluación del desempeño_AÑO 2023_COMPETENCIA
# 38           Desempeño        Evaluación del desempeño_AÑO 2023_RESULTADO
# 39           Desempeño         Evaluación del desempeño_AÑO 2022_OBJETIVO
# 40           Desempeño      Evaluación del desempeño_AÑO 2022_COMPETENCIA
# 41           Desempeño        Evaluación del desempeño_AÑO 2022_RESULTADO
# 42           Desempeño         Evaluación del desempeño_AÑO 2021_OBJETIVO
# 43           Desempeño      Evaluación del desempeño_AÑO 2021_COMPETENCIA
# 44           Desempeño        Evaluación del desempeño_AÑO 2021_RESULTADO
# 45           Desempeño         Evaluación del desempeño_AÑO 2020_OBJETIVO
# 46           Desempeño      Evaluación del desempeño_AÑO 2020_COMPETENCIA
# 47           Desempeño        Evaluación del desempeño_AÑO 2020_RESULTADO
# 48          Engagement               Engagement_AÑO 2025_AMBIENTE LABORAL
# 49          Engagement                     Engagement_AÑO 2025_COMPROMISO

# %% [markdown]
# #### 5.4.2 Análisis de correlaciones
#
# Se analiza la correlación entre las variables numéricas con el propósito de identificar relaciones fuertes y posibles redundancias. La correlación permitirá determinar qué variables presentan comportamientos similares y orientar la construcción de indicadores representativos para cada dimensión.

# %%
# Seleccionar variables numéricas correspondientes a 2025
variables_2025 = [
    col for col in variables_psicosocial + variables_desempeno + variables_engagement
    if '2025' in col
]

print(f"Variables numéricas analizadas: {len(variables_2025)}")

print ("----"*20)

# Matriz de correlación
matriz_correlacion = df_modelo[variables_2025].corr()

# Crear máscara para ocultar la mitad superior
mask = np.triu(np.ones_like(matriz_correlacion, dtype=bool))

# Visualización de la matriz de correlación
plt.figure(figsize=(16, 12))

sns.heatmap(
    matriz_correlacion,
    mask=mask,
    cmap='coolwarm',
    center=0,
    linewidths=0.5,
    annot=True,
    fmt='.2f'
)

plt.title('Matriz de correlación de variables 2025')
plt.tight_layout()
plt.show()
# Out:
# Variables numéricas analizadas: 20
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 18
#      14 # Crear máscara para ocultar la mitad superior
#      15 mask = np.triu(np.ones_like(matriz_correlacion, dtype=bool))
#      16
#      17 # Visualización de la matriz de correlación
# ---> 18 plt.figure(figsize=(16, 12))
#      19
#      20 sns.heatmap(
#      21     matriz_correlacion,
#
# NameError: name 'plt' is not defined

# %%
# Obtener pares de variables con correlaciones fuertes

correlaciones = (
    matriz_correlacion
    .where(np.triu(np.ones(matriz_correlacion.shape), k=1).astype(bool))
    .stack()
    .reset_index()
)

correlaciones.columns = ['Variable 1', 'Variable 2', 'Correlación']

correlaciones[
    correlaciones['Correlación'].abs() >= 0.70
].sort_values(
    'Correlación',
    key=abs,
    ascending=False
)
# Out:
#                                      Variable 1  \
# 379        Engagement_AÑO 2025_AMBIENTE LABORAL
# 317  Evaluación del desempeño_AÑO 2025_OBJETIVO
#
#                                       Variable 2  Correlación
# 379               Engagement_AÑO 2025_COMPROMISO     0.940170
# 317  Evaluación del desempeño_AÑO 2025_RESULTADO     0.919326

# %% [markdown]
# #### 5.4.3 Definición de grupos de variables
#
# A partir de la revisión de las variables y sus relaciones, se establecen grupos conceptuales que representan las principales dimensiones del análisis. La agrupación busca reducir la cantidad de variables utilizadas posteriormente en el modelamiento, evitando que múltiples variables que representan un mismo fenómeno tengan un peso excesivo en el algoritmo de clusterización.
#
# Los grupos iniciales serán:
#
# - **Riesgo Psicosocial:** Estrés, factores intralaborales y factores extralaborales.
# - **Evaluación del Desempeño:** Objetivo, Competencia y Resultado.
# - **Engagement:** Ambiente Laboral y Compromiso.
#
# Estos grupos servirán como base para la construcción de indicadores representativos de cada dimensión.

# %%
# Agrupación conceptual de variables
grupos_variables = {
    'Estres': [
        col for col in variables_2025
        if 'ESTRÉS' in col
    ],
    
    'Intralaboral': [
        col for col in variables_2025
        if 'INTRALABORALES' in col
    ],
    
    'Extralaboral': [
        col for col in variables_2025
        if 'EXTRABORALES' in col
    ],
    
    'Desempeño Objetivo': [
        col for col in variables_2025
        if 'OBJETIVO' in col
    ],
    
    'Desempeño Competencia': [
        col for col in variables_2025
        if 'COMPETENCIA' in col
    ],
    
    'Desempeño Resultado': [
        col for col in variables_2025
        if 'RESULTADO' in col
    ],
    
    'Engagement Ambiente Laboral': [
        col for col in variables_2025
        if 'AMBIENTE LABORAL' in col
    ],
    
    'Engagement Compromiso': [
        col for col in variables_2025
        if 'COMPROMISO' in col
    ]
}

# Mostrar las variables de cada grupo
for grupo, variables in grupos_variables.items():
    print(f"\n{grupo}:")
    for variable in variables:
        print(f"  - {variable}")

print ("----"*20)
        
# Resumen de variables por grupo
resumen_grupos = pd.DataFrame({
    'Grupo': list(grupos_variables.keys()),
    'Cantidad de variables': [
        len(variables) for variables in grupos_variables.values()
    ]
})
resumen_grupos
# Out:
# Estres:
#   - Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy alto
#   - Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto
#   - Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio
#   - Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo
#   - Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo
#
# Intralaboral:
#   - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo muy alto
#   - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo alto
#   - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo medio
#   - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo bajo
#   - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin riesgo
#
# Extralaboral:
#   - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo muy alto
#   - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo alto
#   - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo medio
#   - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo bajo
#   - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin riesgo
#
# Desempeño Objetivo:
#   - Evaluación del desempeño_AÑO 2025_OBJETIVO
#
# Desempeño Competencia:
#   - Evaluación del desempeño_AÑO 2025_COMPETENCIA
#
# Desempeño Resultado:
#   - Evaluación del desempeño_AÑO 2025_RESULTADO
#
# Engagement Ambiente Laboral:
#   - Engagement_AÑO 2025_AMBIENTE LABORAL
#
# Engagement Compromiso:
#   - Engagement_AÑO 2025_COMPROMISO
# --------------------------------------------------------------------------------
#                          Grupo  Cantidad de variables
# 0                       Estres                      5
# 1                 Intralaboral                      5
# 2                 Extralaboral                      5
# 3           Desempeño Objetivo                      1
# 4        Desempeño Competencia                      1
# 5          Desempeño Resultado                      1
# 6  Engagement Ambiente Laboral                      1
# 7        Engagement Compromiso                      1

# %% [markdown]
# ### 5.5 Análisis de Riesgo Psicosocial

# %% [markdown]
# #### 5.5.1 Distribución de los niveles de riesgo
#
# Se analiza la distribución de los niveles de Riesgo Psicosocial en las unidades de tipo Agencia y PDA durante 2025. Para cada componente —Estrés, Intralaboral y Extralaboral— se calculan los valores promedio de las categorías de riesgo: Muy alto, Alto, Medio, Bajo y Sin riesgo. Este análisis permite identificar la concentración general del riesgo y comparar el comportamiento de los tres componentes entre las unidades analizadas.

# %%
# Validar las 20 variables seleccionadas para el análisis

total_variables = sum(len(variables) for variables in grupos_variables.values())

print(f"Total de variables 2025: {total_variables}")
print("-" * 60)

for grupo, variables in grupos_variables.items():
    print(f"\n{grupo}: {len(variables)} variables")
    
    for variable in variables:
        print(f"  - {variable}")
# Out:
# Total de variables 2025: 20
# ------------------------------------------------------------
#
# Estres: 5 variables
#   - Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy alto
#   - Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto
#   - Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio
#   - Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo
#   - Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo
#
# Intralaboral: 5 variables
#   - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo muy alto
#   - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo alto
#   - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo medio
#   - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Riesgo bajo
#   - Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin riesgo
#
# Extralaboral: 5 variables
#   - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo muy alto
#   - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo alto
#   - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo medio
#   - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo bajo
#   - Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin riesgo
#
# Desempeño Objetivo: 1 variables
#   - Evaluación del desempeño_AÑO 2025_OBJETIVO
#
# Desempeño Competencia: 1 variables
#   - Evaluación del desempeño_AÑO 2025_COMPETENCIA
#
# Desempeño Resultado: 1 variables
#   - Evaluación del desempeño_AÑO 2025_RESULTADO
#
# Engagement Ambiente Laboral: 1 variables
#   - Engagement_AÑO 2025_AMBIENTE LABORAL
#
# Engagement Compromiso: 1 variables
#   - Engagement_AÑO 2025_COMPROMISO

# %%
# Variables de Riesgo Psicosocial 2025 por componente

grupos_riesgo = {
    'Estrés': grupos_variables['Estres'],
    'Intralaboral': grupos_variables['Intralaboral'],
    'Extralaboral': grupos_variables['Extralaboral']
}

# Calcular el promedio de cada categoría de riesgo
resumen_riesgo = pd.DataFrame({
    componente: df_modelo[variables].mean()
    for componente, variables in grupos_riesgo.items()
})

resumen_riesgo
# Out:
#                                                       Estrés  Intralaboral  \
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto      0.201255           NaN
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo      0.172006           NaN
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio     0.168790           NaN
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy alto  0.301177           NaN
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo       0.156772           NaN
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...       NaN           NaN
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...       NaN           NaN
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...       NaN           NaN
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...       NaN           NaN
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin ri...       NaN           NaN
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...       NaN      0.186881
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...       NaN      0.210308
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...       NaN      0.209583
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...       NaN      0.158916
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin ...       NaN      0.234312
#
#                                                     Extralaboral
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo alto               NaN
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo bajo               NaN
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo medio              NaN
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Riesgo muy alto           NaN
# Riesgo psicosocial_AÑO 2025_ESTRÉS_Sin riesgo                NaN
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...      0.192779
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...      0.164409
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...      0.213287
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Riesgo...      0.136956
# Riesgo psicosocial_AÑO 2025_EXTRABORALES_Sin ri...      0.292568
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...           NaN
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...           NaN
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...           NaN
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Ries...           NaN
# Riesgo psicosocial_AÑO 2025_INTRALABORALES_Sin ...           NaN

# %%
# Categorías de riesgo
categorias_riesgo = [
    'Riesgo muy alto',
    'Riesgo alto',
    'Riesgo medio',
    'Riesgo bajo',
    'Sin riesgo'
]

# Crear tabla resumen
resumen_riesgo = pd.DataFrame(index=categorias_riesgo)

for componente, variables in grupos_riesgo.items():
    resumen_riesgo[componente] = [
        df_modelo[variables[i]].mean()
        for i in range(len(variables))
    ]

# Convertir a porcentaje
resumen_riesgo = (resumen_riesgo * 100).round(2)

resumen_riesgo
# Out:
#                  Estrés  Intralaboral  Extralaboral
# Riesgo muy alto   30.12         15.89         13.70
# Riesgo alto       20.13         18.69         19.28
# Riesgo medio      16.88         20.96         21.33
# Riesgo bajo       17.20         21.03         16.44
# Sin riesgo        15.68         23.43         29.26

# %%
# Gráfico de distribución promedio del Riesgo Psicosocial

colores_riesgo = [
    '#B71C1C',  # Riesgo muy alto
    '#E53935',  # Riesgo alto
    '#FB8C00',  # Riesgo medio
    '#FDD835',  # Riesgo bajo
    '#66BB6A'   # Sin riesgo
]

ax = resumen_riesgo.T.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 6),
    color=colores_riesgo
)

# Agregar etiquetas con los valores dentro de cada segmento
for i, componente in enumerate(resumen_riesgo.columns):
    
    acumulado = 0
    
    for categoria in resumen_riesgo.index:
        
        valor = resumen_riesgo.loc[categoria, componente]
        
        # Solo mostrar etiquetas si el segmento tiene un valor significativo
        if valor >= 3:
            ax.text(
                i,
                acumulado + valor / 2,
                f'{valor:.1f}%',
                ha='center',
                va='center',
                fontsize=9,
                fontweight='bold'
            )
        
        acumulado += valor

plt.title('Distribución promedio de los niveles de Riesgo Psicosocial - 2025')
plt.xlabel('Componente')
plt.ylabel('Porcentaje promedio (%)')
plt.xticks(rotation=0)

plt.legend(
    title='Nivel de riesgo',
    bbox_to_anchor=(1.02, 1),
    loc='upper left'
)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 41
#      37             )
#      38
#      39         acumulado += valor
#      40
# ---> 41 plt.title('Distribución promedio de los niveles de Riesgo Psicosocial - 2025')
#      42 plt.xlabel('Componente')
#      43 plt.ylabel('Porcentaje promedio (%)')
#      44 plt.xticks(rotation=0)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# #### 5.5.2 Comparación entre Estrés, Intralaboral y Extralaboral
#
# Para facilitar la comparación entre los componentes del Riesgo Psicosocial, se agrupan las categorías de **Riesgo muy alto** y **Riesgo alto** como niveles de mayor prioridad. Se calcula el porcentaje promedio de unidades que presentan estos niveles de riesgo para Estrés, Intralaboral y Extralaboral. Este indicador permite identificar qué componente concentra una mayor proporción de riesgo elevado y proporciona una primera aproximación para la posterior construcción de indicadores utilizados en el modelo de clusterización.

# %%
# Visualización comparativa
ax = comparacion_riesgo.T.plot(
    kind='bar',
    figsize=(9, 5),
    legend=False
)

plt.title('Proporción promedio de Riesgo Alto y Muy Alto - 2025')
plt.xlabel('Componente')
plt.ylabel('Porcentaje promedio (%)')
plt.xticks(rotation=0)

# Etiquetas de valores
for container in ax.containers:
    ax.bar_label(
        container,
        fmt='%.1f%%',
        padding=3
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5.5.3 Hallazgos principales
#
# El análisis de Riesgo Psicosocial para las 186 unidades de tipo Agencia y PDA evidencia diferencias entre los tres componentes evaluados. La proporción promedio de riesgo alto y muy alto es mayor en **Estrés**, seguido de **Intralaboral** y **Extralaboral**. Esto indica que el componente de Estrés concentra la mayor exposición relativa a niveles elevados de riesgo entre las unidades analizadas. Estos resultados permiten identificar al Estrés como un componente relevante para la caracterización posterior de las oficinas y constituyen un insumo para la construcción de indicadores utilizados en el modelo de clusterización.

# %% [markdown]
# ### 5.6 Análisis de Evaluación del Desempeño

# %% [markdown]
# Se analiza el comportamiento de la Evaluación del Desempeño correspondiente a 2025 para las unidades de tipo Agencia y PDA. El análisis considera los componentes de Objetivo, Competencia y Resultado, con el propósito de identificar diferencias en el desempeño de las unidades y establecer los principales hallazgos que serán considerados posteriormente en la construcción de indicadores para el modelo de clusterización.

# %% [markdown]
# #### 5.6.1 Distribución de los resultados de desempeño
#
# Se analiza la distribución de los resultados obtenidos en los componentes de Objetivo, Competencia y Resultado durante 2025. Se calculan medidas descriptivas como promedio, mediana, mínimo y máximo, con el fin de conocer el comportamiento general del desempeño entre las unidades analizadas.

# %%
# Preparar datos para visualización
datos_desempeno = df_modelo[variables_desempeno_2025].copy()

# Renombrar columnas para facilitar la lectura
datos_desempeno.columns = ['Objetivo', 'Competencia', 'Resultado']

# Gráfico de distribución
plt.figure(figsize=(9, 6))

sns.boxplot(data=datos_desempeno)

plt.title('Distribución de los componentes de Evaluación del Desempeño - 2025')
plt.xlabel('Componente')
plt.ylabel('Resultado')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5.6.2 Comparación entre Objetivo, Competencia y Resultado
#
# Se comparan los valores promedio de los tres componentes de la Evaluación del Desempeño para identificar cuál presenta el mayor y menor resultado promedio entre las unidades analizadas. A diferencia del Riesgo Psicosocial, en esta dimensión un resultado más alto representa un mejor desempeño. Esta dirección deberá conservarse durante la preparación de los datos para el modelo de clusterización.

# %%
# Gráfico de promedio por componente
ax = promedio_desempeno.plot(
    kind='bar',
    figsize=(9, 5)
)

plt.title('Promedio de los componentes de Evaluación del Desempeño - 2025')
plt.xlabel('Componente')
plt.ylabel('Promedio')
plt.xticks(rotation=0)

# Etiquetas
for container in ax.containers:
    ax.bar_label(
        container,
        fmt='%.2f',
        padding=3
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5.6.3 Hallazgos principales
#
# La Evaluación del Desempeño de 2025 presenta un comportamiento favorable entre las unidades analizadas. Se identifican diferencias en los resultados promedio de los componentes de Objetivo, Competencia y Resultado, las cuales permiten caracterizar distintos niveles de desempeño. Los resultados muestran que los componentes de desempeño pueden utilizarse como indicadores diferenciadores entre oficinas. Para el posterior modelo de clusterización se deberá considerar que, a diferencia del Riesgo Psicosocial, un mayor resultado de desempeño representa una condición favorable.

# %% [markdown]
# ### 5.7 Análisis de Engagement

# %% [markdown]
# Se analiza el comportamiento del Engagement durante 2025 en las unidades de tipo Agencia y PDA. El análisis considera los componentes de Ambiente Laboral y Compromiso, con el propósito de identificar diferencias entre las unidades y establecer los principales hallazgos que serán utilizados posteriormente en la construcción de indicadores para el modelo de clusterización.

# %% [markdown]
# #### 5.7.1 Distribución de los resultados de Engagement
#
# Se analiza la distribución de los resultados de Ambiente Laboral y Compromiso durante 2025 mediante medidas descriptivas y representaciones gráficas. Este análisis permite identificar el nivel general de Engagement y la dispersión de los resultados entre las unidades analizadas.

# %%
# Identificar variables numéricas de Engagement 2025
variables_engagement_2025 = [
    col for col in variables_engagement
    if '2025' in col
    and 'INTERPRETACION' not in col.upper()
]
print(f"Variables de Engagement 2025: {len(variables_engagement_2025)}")

for variable in variables_engagement_2025:
    print(f"- {variable}")
    
# Preparar datos para visualización
datos_engagement = df_modelo[variables_engagement_2025].copy()
datos_engagement.columns = [
    'Ambiente Laboral',
    'Compromiso'
]

# Gráfico de distribución
plt.figure(figsize=(9, 6))
sns.boxplot(data=datos_engagement)
plt.title('Distribución de los componentes de Engagement - 2025')
plt.xlabel('Componente')
plt.ylabel('Resultado')
plt.tight_layout()
plt.show()
# Out:
# Variables de Engagement 2025: 2
# - Engagement_AÑO 2025_AMBIENTE LABORAL
# - Engagement_AÑO 2025_COMPROMISO

# %% [markdown]
# #### 5.7.2 Comparación entre Ambiente Laboral y Compromiso
#
# Se comparan los resultados promedio de Ambiente Laboral y Compromiso para identificar diferencias en el comportamiento de ambos componentes entre las unidades analizadas. En esta dimensión, al igual que en Evaluación del Desempeño, un resultado más alto representa una condición favorable. Por lo tanto, durante la preparación de los datos para el modelo de clusterización, los valores bajos serán interpretados como una mayor vulnerabilidad.

# %%
# Calcular promedio de cada componente
promedio_engagement = (
    datos_engagement
    .mean()
    .sort_values(ascending=False)
)
promedio_engagement.round(3)

# Gráfico de promedio por componente
ax = promedio_engagement.plot(
    kind='bar',
    figsize=(9, 5)
)

plt.title('Promedio de los componentes de Engagement - 2025')
plt.xlabel('Componente')
plt.ylabel('Promedio')
plt.xticks(rotation=0)

# Etiquetas de valores
for container in ax.containers:
    ax.bar_label(
        container,
        fmt='%.2f',
        padding=3
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5.7.3 Hallazgos principales
#
# El análisis de Engagement permite identificar el comportamiento de los componentes de Ambiente Laboral y Compromiso entre las unidades analizadas. Ambos indicadores presentan información complementaria sobre la experiencia de los colaboradores y pueden utilizarse para diferenciar los perfiles de las oficinas. Para el posterior modelo de clusterización se conservarán ambos componentes como indicadores independientes, considerando que valores más bajos representan una condición menos favorable y, por tanto, una mayor vulnerabilidad potencial.

# %% [markdown]
# #### Resumen del proceso de reducción
#
# ```text
# 50 variables numéricas
#         ↓
# Selección de variables 2025
#         ↓
# 20 variables
#         ↓
# Agrupación conceptual
#         ↓
# 8 grupos de indicadores
#
# ┌─────────────────────────────────────┐
# │ 🧠 Riesgo Psicosocial               │
# │                                     │
# │   ├── Estrés                        │
# │   ├── Intralaboral                  │
# │   └── Extralaboral                  │
# │                                     │
# │ 🎯 Evaluación del Desempeño         │
# │                                     │
# │   ├── Objetivo                      │
# │   ├── Competencia                   │
# │   └── Resultado                     │
# │                                     │
# │ ❤️ Engagement                       │
# │                                     │
# │   ├── Ambiente Laboral              │
# │   └── Compromiso                    │
# └─────────────────────────────────────┘

# %% [markdown]
# ### 5.8 Relación entre las dimensiones

# %% [markdown]
# Con el propósito de analizar la relación existente entre las tres dimensiones del estudio, se construyen indicadores resumidos para cada componente. Para Riesgo Psicosocial se utiliza la proporción de riesgo alto y muy alto de cada componente. Para Evaluación del Desempeño se conserva el resultado promedio de Objetivo, Competencia y Resultado, mientras que para Engagement se utilizan los resultados de Ambiente Laboral y Compromiso. Estos indicadores permiten reducir la dimensionalidad y analizar las relaciones entre las dimensiones antes de definir las variables que serán utilizadas en el modelo de clusterización.

# %% [markdown]
# #### 5.8.1 Construcción de indicadores resumidos
#
# Se construyen ocho indicadores representativos de las tres dimensiones analizadas. Los indicadores de Riesgo Psicosocial representan una condición desfavorable cuando presentan valores altos, mientras que los indicadores de Desempeño y Engagement representan una condición favorable cuando presentan valores altos. Esta diferenciación será considerada posteriormente en la preparación de los datos para el modelo de clusterización.

# %%
# Crear DataFrame con los indicadores resumidos

indicadores = pd.DataFrame(index=df_modelo.index)

# --------------------------------------------------
# RIESGO PSICOSOCIAL
# --------------------------------------------------

# Estrés: Riesgo alto + muy alto
indicadores['Riesgo_Estres'] = (
    df_modelo[grupos_riesgo['Estrés']]
    .filter(regex='Riesgo muy alto|Riesgo alto')
    .sum(axis=1)
)

# Intralaboral: Riesgo alto + muy alto
indicadores['Riesgo_Intralaboral'] = (
    df_modelo[grupos_riesgo['Intralaboral']]
    .filter(regex='Riesgo muy alto|Riesgo alto')
    .sum(axis=1)
)

# Extralaboral: Riesgo alto + muy alto
indicadores['Riesgo_Extralaboral'] = (
    df_modelo[grupos_riesgo['Extralaboral']]
    .filter(regex='Riesgo muy alto|Riesgo alto')
    .sum(axis=1)
)

# --------------------------------------------------
# DESEMPEÑO
# --------------------------------------------------

indicadores['Desempeno_Objetivo'] = (
    df_modelo[variables_desempeno_2025]
    .filter(regex='OBJETIVO')
    .iloc[:, 0]
)

indicadores['Desempeno_Competencia'] = (
    df_modelo[variables_desempeno_2025]
    .filter(regex='COMPETENCIA')
    .iloc[:, 0]
)

indicadores['Desempeno_Resultado'] = (
    df_modelo[variables_desempeno_2025]
    .filter(regex='RESULTADO')
    .iloc[:, 0]
)

# --------------------------------------------------
# ENGAGEMENT
# --------------------------------------------------

indicadores['Engagement_Ambiente'] = (
    df_modelo[variables_engagement_2025]
    .filter(regex='AMBIENTE LABORAL')
    .iloc[:, 0]
)

indicadores['Engagement_Compromiso'] = (
    df_modelo[variables_engagement_2025]
    .filter(regex='COMPROMISO')
    .iloc[:, 0]
)

# Visualizar los indicadores
indicadores.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[152], line 11
#       7 # --------------------------------------------------
#       8
#       9 # Estrés: Riesgo alto + muy alto
#      10 indicadores['Riesgo_Estres'] = (
# ---> 11     df_modelo[grupos_riesgo['Estrés']]
#      12     .filter(regex='Riesgo muy alto|Riesgo alto')
#      13     .sum(axis=1)
#      14 )
#
# NameError: name 'grupos_riesgo' is not defined

# %% [markdown]
# #### 5.8.2 Análisis de correlaciones
#
# Se calcula la matriz de correlación entre los ocho indicadores resumidos para identificar relaciones lineales entre los componentes de Riesgo Psicosocial, Evaluación del Desempeño y Engagement. Las correlaciones permiten identificar posibles relaciones entre variables y detectar indicadores altamente relacionados que puedan aportar información redundante al modelo de clusterización.

# %%
# Matriz de correlación
matriz_correlacion_indicadores = indicadores.corr()

# Crear máscara para ocultar la mitad superior
mascara = np.triu(
    np.ones_like(matriz_correlacion_indicadores, dtype=bool),
    k=1
)

# Visualización de la matriz
plt.figure(figsize=(8, 6))

sns.heatmap(
    matriz_correlacion_indicadores,
    mask=mascara,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    center=0,
    linewidths=0.5,
    vmin=-1,
    vmax=1
)

plt.title('Correlación entre indicadores resumidos - 2025')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[133], line 2
#       1 # Matriz de correlación
# ----> 2 matriz_correlacion_indicadores = indicadores.corr()
#       3
#       4 # Crear máscara para ocultar la mitad superior
#       5 mascara = np.triu(
#
# NameError: name 'indicadores' is not defined

# %% [markdown]
# #### 5.8.3 Identificación de relaciones relevantes
#
# Se identifican las relaciones más fuertes entre los indicadores mediante el coeficiente de correlación de Pearson. Este análisis permite determinar si existen variables con alta asociación que puedan generar redundancia y, por tanto, requerir una revisión antes de incorporarlas al modelo de clusterización.

# %%
# Obtener correlaciones entre pares de variables
correlaciones = (
    matriz_correlacion_indicadores
    .where(
        np.triu(
            np.ones(matriz_correlacion_indicadores.shape),
            k=1
        ).astype(bool)
    )
    .stack()
    .reset_index()
)

correlaciones.columns = ['Variable 1', 'Variable 2', 'Correlación']

# Agregar valor absoluto para ordenar por fuerza de relación
correlaciones['Abs_Correlación'] = (
    correlaciones['Correlación'].abs()
)

correlaciones = (
    correlaciones
    .sort_values('Abs_Correlación', ascending=False)
    .drop(columns='Abs_Correlación')
)

correlaciones.round(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[132], line 3
#       1 # Obtener correlaciones entre pares de variables
#       2 correlaciones = (
# ----> 3     matriz_correlacion_indicadores
#       4     .where(
#       5         np.triu(
#       6             np.ones(matriz_correlacion_indicadores.shape),
#
# NameError: name 'matriz_correlacion_indicadores' is not defined

# %%
# Correlaciones fuertes

correlaciones_fuertes = correlaciones[
    correlaciones['Correlación'].abs() >= 0.70
]

correlaciones_fuertes.round(3)
# Out:
#                                      Variable 1  \
# 317  Evaluación del desempeño_AÑO 2025_OBJETIVO
# 379        Engagement_AÑO 2025_AMBIENTE LABORAL
#
#                                       Variable 2  Correlación
# 317  Evaluación del desempeño_AÑO 2025_RESULTADO        0.919
# 379               Engagement_AÑO 2025_COMPROMISO        0.940

# %% [markdown]
# #### 5.8.3 Reducción de indicadores
#
# El análisis de correlaciones permitió identificar relaciones fuertes entre algunos indicadores que aportan información similar. Se identificó una correlación de **0.94 entre Ambiente Laboral y Compromiso**, por lo que ambos indicadores se integran en un único indicador de Engagement. De igual manera, se encontró una correlación de **0.92 entre Objetivo y Resultado** dentro de la Evaluación del Desempeño. Por esta razón, ambos componentes se integran en un indicador general de Desempeño, mientras que Competencia se conserva como un indicador independiente.
#
# Los tres componentes de Riesgo Psicosocial presentan correlaciones moderadas, por lo que se mantienen separados para conservar las diferencias entre Estrés, Intralaboral y Extralaboral. Como resultado, se reduce el conjunto de análisis de **8 a 6 indicadores**, disminuyendo la redundancia sin perder las principales dimensiones del problema.

# %% [markdown]
# #### Reducción final de indicadores
#
# ```text
# 8 indicadores
#        ↓
# Análisis de correlaciones
#        ↓
# Identificación de alta redundancia
#        ↓
# 6 indicadores finales
#
#
# ┌─────────────────────────────────────┐
# │ 🧠 RIESGO PSICOSOCIAL              │
# │                                     │
# │   ├── Riesgo Estrés                 │
# │   ├── Riesgo Intralaboral           │
# │   └── Riesgo Extralaboral           │
# │                                     │
# │ 🎯 DESEMPEÑO                        │
# │                                     │
# │   ├── Desempeño General             │
# │   └── Competencia                   │
# │                                     │
# │ ❤️ ENGAGEMENT                       │
# │                                     │
# │   └── Engagement General             │
# └─────────────────────────────────────┘

# %%
# ============================================================
# CONSTRUCCIÓN DE LOS 6 INDICADORES FINALES
# ============================================================
indicadores_6 = pd.DataFrame(index=df_modelo.index)
# ------------------------------------------------------------
# 1. RIESGO PSICOSOCIAL
# ------------------------------------------------------------
indicadores_6['Riesgo_Estres'] = indicadores['Riesgo_Estres']
indicadores_6['Riesgo_Intralaboral'] = indicadores['Riesgo_Intralaboral']
indicadores_6['Riesgo_Extralaboral'] = indicadores['Riesgo_Extralaboral']
# ------------------------------------------------------------
# 2. DESEMPEÑO
# ------------------------------------------------------------
# Objetivo y Resultado presentan alta correlación (0.92),
# por lo que se integran en un indicador general.
indicadores_6['Desempeno_General'] = (
    indicadores[
        ['Desempeno_Objetivo', 'Desempeno_Resultado']
    ]
    .mean(axis=1)
)
# Competencia se conserva como indicador independiente
indicadores_6['Desempeno_Competencia'] = (
    indicadores['Desempeno_Competencia']
)
# ------------------------------------------------------------
# 3. ENGAGEMENT
# ------------------------------------------------------------
# Ambiente Laboral y Compromiso presentan alta correlación (0.94),
# por lo que se integran en un único indicador.
indicadores_6['Engagement_General'] = (
    indicadores[
        ['Engagement_Ambiente', 'Engagement_Compromiso']
    ]
    .mean(axis=1)
)

# Estadísticas descriptivas de los 6 indicadores
indicadores_6.describe().T.round(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[130], line 8
#       4 indicadores_6 = pd.DataFrame(index=df_modelo.index)
#       5 # ------------------------------------------------------------
#       6 # 1. RIESGO PSICOSOCIAL
#       7 # ------------------------------------------------------------
# ----> 8 indicadores_6['Riesgo_Estres'] = indicadores['Riesgo_Estres']
#       9 indicadores_6['Riesgo_Intralaboral'] = indicadores['Riesgo_Intralaboral']
#      10 indicadores_6['Riesgo_Extralaboral'] = indicadores['Riesgo_Extralaboral']
#      11 # ------------------------------------------------------------
#
# NameError: name 'indicadores' is not defined

# %% [markdown]
# ### 5.9 Hallazgos principales

# %% [markdown]
# El análisis exploratorio permitió caracterizar las unidades de tipo Agencia y PDA y establecer una estructura de variables adecuada para el posterior modelamiento no supervisado. Inicialmente se identificaron **50 variables numéricas**. Debido a que el conjunto de datos contiene información de diferentes periodos, se seleccionaron las variables correspondientes a **2025**, obteniendo 20 variables relacionadas con Riesgo Psicosocial, Evaluación del Desempeño y Engagement.
#
# El análisis conceptual permitió organizar estas variables en ocho indicadores. Posteriormente, el análisis de correlaciones identificó relaciones altamente significativas entre algunos componentes, especialmente entre **Ambiente Laboral y Compromiso (r = 0.94)** y entre **Objetivo y Resultado (r = 0.92)**. Con base en estas relaciones, se redujo el conjunto de variables a **seis indicadores finales**, buscando disminuir la redundancia y conservar la información relevante para diferenciar los perfiles de las oficinas.
#
# Los indicadores seleccionados son:
#
# - **Riesgo Psicosocial:** Riesgo Estrés, Riesgo Intralaboral y Riesgo Extralaboral.
# - **Desempeño:** Desempeño General y Competencia.
# - **Engagement:** Engagement General.
#
# Para la interpretación de los indicadores se considera la dirección de cada dimensión: en Riesgo Psicosocial, valores altos representan una condición desfavorable; mientras que en Desempeño y Engagement, valores altos representan una condición favorable. Los valores faltantes identificados durante el análisis serán tratados en la etapa de preparación de datos del modelo, evitando asumir que la ausencia de medición representa una condición favorable o desfavorable. De esta manera, el análisis exploratorio permite pasar de un conjunto inicial de alta dimensionalidad a una estructura de seis indicadores interpretables, que serán evaluados y preparados para el modelo de clusterización.

# %% [markdown]
# ## 6. 🧮 Modelamiento no supervisado: Clusterización de oficinas

# %% [markdown]
# ### 6.1 Objetivo y selección de variables

# %% [markdown]
# El objetivo de esta etapa es construir un modelo de **clusterización no supervisado** que permita agrupar las oficinas según patrones similares en Riesgo Psicosocial, Evaluación del Desempeño y Engagement. Se utilizará el algoritmo **K-Means**, evaluando diferentes cantidades de grupos y priorizando la comparación entre soluciones de **4 y 5 clusters**. El modelo buscará identificar perfiles diferenciados de oficinas, sin establecer previamente categorías de vulnerabilidad. Posteriormente, estos perfiles serán interpretados de acuerdo con sus características de riesgo, desempeño y engagement.
#
# Como resultado del análisis exploratorio, se seleccionaron seis indicadores finales:
#
# - **Riesgo Psicosocial:** Riesgo Estrés, Riesgo Intralaboral y Riesgo Extralaboral.
# - **Desempeño:** Desempeño General y Competencia.
# - **Engagement:** Engagement General.
#
# Estos indicadores constituyen las variables de entrada iniciales para el modelo de clusterización.

# %% [markdown]
# ### 6.2 Preparación de los datos

# %% [markdown]
# Para aplicar el algoritmo K-Means es necesario preparar los indicadores seleccionados en la etapa anterior. El conjunto de modelamiento estará conformado por los seis indicadores definidos para las oficinas de tipo Agencia y PDA. En esta etapa los indicadores serán estandarizados mediante `StandardScaler`, con el objetivo de llevarlos a una escala comparable y evitar que una variable tenga mayor influencia en el cálculo de las distancias debido únicamente a su magnitud. La dirección conceptual de los indicadores también será considerada durante la interpretación de los resultados: valores altos de Riesgo Psicosocial representan mayor exposición al riesgo, mientras que valores altos de Desempeño y Engagement representan mejores condiciones.

# %%
# Copia de los indicadores seleccionados para el modelamiento

df_cluster = indicadores_6.copy()

# Agregar información de identificación de las oficinas

df_cluster['CODIGO UNIDAD'] = df_modelo['CODIGO UNIDAD']
df_cluster['REGIONAL'] = df_modelo['REGIONAL']
df_cluster['TIPO'] = df_modelo['TIPO']

# Visualizar estructura

df_cluster.head()
# Out:
#   CODIGO UNIDAD REGIONAL TIPO
# 1  A411243         CAUCA  PDA
# 2  A411242         CAUCA  PDA
# 3  A411221         CAUCA  PDA
# 4  A411241         CAUCA  PDA
# 5  A411231         CAUCA  PDA
